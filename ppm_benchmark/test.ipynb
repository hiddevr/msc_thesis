# %%
import pandas as pd

df = pd.read_csv('test.csv')
df
# Out:
#         Unnamed: 0 isCancelled diagnosis             time:timestamp caseType  \
# 0                0       False         A  2012-12-16 19:33:10+00:00        A
# 1                1         NaN       NaN  2013-12-15 19:00:37+00:00      NaN
# 2                2         NaN       NaN  2013-12-16 03:53:38+00:00      NaN
# 3                3         NaN       NaN  2013-12-17 12:56:29+00:00      NaN
# 4                4         NaN       NaN  2013-12-19 03:44:31+00:00      NaN
# ...            ...         ...       ...                        ...      ...
# 451354      451354       False        OM  2015-12-13 19:31:23+00:00        A
# 451355      451355       False       NaN  2016-01-14 21:17:47+00:00        B
# 451356      451356        True       NaN  2016-01-14 22:00:13+00:00      NaN
# 451357      451357       False        LL  2016-01-11 19:40:47+00:00        A
# 451358      451358       False       NaN  2016-01-13 22:48:13+00:00        I
#
#        speciality org:resource concept:name blocked isClosed  ...  \
# 0               A         ResA          NEW   False     True  ...
# 1             NaN          NaN          FIN     NaN      NaN  ...
# 2             NaN          NaN      RELEASE     NaN      NaN  ...
# 3             NaN          NaN      CODE OK     NaN      NaN  ...
# 4             NaN         ResB       BILLED     NaN      NaN  ...
# ...           ...          ...          ...     ...      ...  ...
# 451354          E         ResA          NEW   False    False  ...
# 451355          L        ResDJ          NEW   False    False  ...
# 451356        NaN        ResFR       DELETE     NaN      NaN  ...
# 451357          D         ResA          NEW   False    False  ...
# 451358          K        ResJA          NEW   False     True  ...
#
#        lifecycle:transition case:concept:name closeCode actRed actOrange  \
# 0                  complete                 A       NaN    NaN       NaN
# 1                  complete                 A         A    NaN       NaN
# 2                  complete                 A       NaN    NaN       NaN
# 3                  complete                 A       NaN  False     False
# 4                  complete                 A       NaN    NaN       NaN
# ...                     ...               ...       ...    ...       ...
# 451354             complete              AXQE       NaN    NaN       NaN
# 451355             complete              BXQE       NaN    NaN       NaN
# 451356             complete              BXQE       NaN    NaN       NaN
# 451357             complete              CXQE       NaN    NaN       NaN
# 451358             complete              DXQE       NaN    NaN       NaN
#
#         flagC msgCount version msgType msgCode
# 0         NaN      NaN     NaN     NaN     NaN
# 1         NaN      NaN     NaN     NaN     NaN
# 2         NaN      NaN     NaN     NaN     NaN
# 3       False      0.0       A     NaN     NaN
# 4         NaN      NaN     NaN     NaN     NaN
# ...       ...      ...     ...     ...     ...
# 451354    NaN      NaN     NaN     NaN     NaN
# 451355    NaN      NaN     NaN     NaN     NaN
# 451356    NaN      NaN     NaN     NaN     NaN
# 451357    NaN      NaN     NaN     NaN     NaN
# 451358    NaN      NaN     NaN     NaN     NaN
#
# [451359 rows x 24 columns]

# %%
unique_cases = df['case:concept:name'].unique()
num_cases = len(unique_cases)
split_index = int(num_cases * 0.8)
train_cases = unique_cases[:split_index]
test_cases = unique_cases[split_index:]

train_df = df[df['case:concept:name'].isin(train_cases)]
test_df = df[df['case:concept:name'].isin(test_cases)]

# %%
grouped = test_df.groupby('case:concept:name')
last_values = grouped['concept:name'].apply(lambda x: x.iloc[-1])
last_values_dict = last_values.to_dict()
last_values_dict
# Out:
# {'AAAE': 'FIN',
#  'AABE': 'BILLED',
#  'AACE': 'NEW',
#  'AADE': 'NEW',
#  'AAEE': 'BILLED',
#  'AAFE': 'DELETE',
#  'AAGE': 'NEW',
#  'AAHE': 'NEW',
#  'AAIE': 'NEW',
#  'AAJE': 'NEW',
#  'AAKE': 'DELETE',
#  'AALE': 'NEW',
#  'AAME': 'BILLED',
#  'AANE': 'DELETE',
#  'AAOD': 'BILLED',
#  'AAOE': 'NEW',
#  'AAPD': 'NEW',
#  'AAPE': 'NEW',
#  'AAQD': 'DELETE',
#  'AAQE': 'NEW',
#  'AARD': 'BILLED',
#  'AASD': 'NEW',
#  'AATD': 'NEW',
#  'AAUD': 'BILLED',
#  'AAVD': 'NEW',
#  'AAWD': 'BILLED',
#  'AAXD': 'BILLED',
#  'AAYD': 'BILLED',
#  'AAZD': 'BILLED',
#  'ABAE': 'BILLED',
#  'ABBE': 'BILLED',
#  'ABCE': 'FIN',
#  'ABDE': 'BILLED',
#  'ABEE': 'BILLED',
#  'ABFE': 'DELETE',
#  'ABGE': 'BILLED',
#  'ABHE': 'NEW',
#  'ABIE': 'NEW',
#  'ABJE': 'BILLED',
#  'ABKE': 'BILLED',
#  'ABLE': 'NEW',
#  'ABME': 'DELETE',
#  'ABNE': 'NEW',
#  'ABOD': 'DELETE',
#  'ABOE': 'NEW',
#  'ABPD': 'NEW',
#  'ABPE': 'FIN',
#  'ABQD': 'DELETE',
#  'ABQE': 'DELETE',
#  'ABRD': 'BILLED',
#  'ABSD': 'NEW',
#  'ABTD': 'NEW',
#  'ABUD': 'DELETE',
#  'ABVD': 'NEW',
#  'ABWD': 'BILLED',
#  'ABXD': 'BILLED',
#  'ABYD': 'BILLED',
#  'ABZD': 'SET STATUS',
#  'ACAE': 'BILLED',
#  'ACBE': 'BILLED',
#  'ACCE': 'FIN',
#  'ACDE': 'FIN',
#  'ACEE': 'FIN',
#  'ACFE': 'FIN',
#  'ACGE': 'BILLED',
#  'ACHE': 'BILLED',
#  'ACIE': 'NEW',
#  'ACJE': 'RELEASE',
#  'ACKE': 'BILLED',
#  'ACLE': 'DELETE',
#  'ACME': 'NEW',
#  'ACNE': 'DELETE',
#  'ACOD': 'NEW',
#  'ACOE': 'NEW',
#  'ACPD': 'NEW',
#  'ACPE': 'NEW',
#  'ACQD': 'BILLED',
#  'ACQE': 'NEW',
#  'ACRD': 'BILLED',
#  'ACSD': 'NEW',
#  'ACTD': 'NEW',
#  'ACUD': 'BILLED',
#  'ACVD': 'NEW',
#  'ACWD': 'FIN',
#  'ACXD': 'BILLED',
#  'ACYD': 'BILLED',
#  'ACZD': 'NEW',
#  'ADAE': 'BILLED',
#  'ADBE': 'DELETE',
#  'ADCE': 'NEW',
#  'ADDE': 'NEW',
#  'ADEE': 'BILLED',
#  'ADFE': 'DELETE',
#  'ADGE': 'BILLED',
#  'ADHE': 'NEW',
#  'ADIE': 'BILLED',
#  'ADJE': 'NEW',
#  'ADKE': 'BILLED',
#  'ADLE': 'FIN',
#  'ADME': 'DELETE',
#  'ADNE': 'FIN',
#  'ADOD': 'BILLED',
#  'ADOE': 'NEW',
#  'ADPD': 'BILLED',
#  'ADPE': 'NEW',
#  'ADQD': 'BILLED',
#  'ADQE': 'NEW',
#  'ADRD': 'BILLED',
#  'ADSD': 'DELETE',
#  'ADTD': 'NEW',
#  'ADUD': 'DELETE',
#  'ADVD': 'NEW',
#  'ADWD': 'BILLED',
#  'ADXD': 'BILLED',
#  'ADYD': 'FIN',
#  'ADZD': 'NEW',
#  'AEAE': 'BILLED',
#  'AEBE': 'NEW',
#  'AECE': 'BILLED',
#  'AEDE': 'DELETE',
#  'AEEE': 'BILLED',
#  'AEFE': 'DELETE',
#  'AEGE': 'SET STATUS',
#  'AEHE': 'NEW',
#  'AEIE': 'FIN',
#  'AEJE': 'NEW',
#  'AEKE': 'NEW',
#  'AELE': 'FIN',
#  'AEME': 'NEW',
#  'AENE': 'DELETE',
#  'AEOD': 'BILLED',
#  'AEOE': 'NEW',
#  'AEPD': 'BILLED',
#  'AEPE': 'NEW',
#  'AEQD': 'BILLED',
#  'AEQE': 'NEW',
#  'AERD': 'BILLED',
#  'AESD': 'FIN',
#  'AETD': 'NEW',
#  'AEUD': 'DELETE',
#  'AEVD': 'NEW',
#  'AEWD': 'BILLED',
#  'AEXD': 'NEW',
#  'AEYD': 'NEW',
#  'AEZD': 'DELETE',
#  'AFAE': 'BILLED',
#  'AFBE': 'BILLED',
#  'AFCE': 'BILLED',
#  'AFDE': 'BILLED',
#  'AFEE': 'FIN',
#  'AFFE': 'BILLED',
#  'AFGE': 'FIN',
#  'AFHE': 'FIN',
#  'AFIE': 'DELETE',
#  'AFJE': 'NEW',
#  'AFKE': 'BILLED',
#  'AFLE': 'NEW',
#  'AFME': 'FIN',
#  'AFNE': 'FIN',
#  'AFOD': 'BILLED',
#  'AFOE': 'NEW',
#  'AFPD': 'FIN',
#  'AFPE': 'NEW',
#  'AFQD': 'BILLED',
#  'AFQE': 'NEW',
#  'AFRD': 'BILLED',
#  'AFSD': 'BILLED',
#  'AFTD': 'NEW',
#  'AFUD': 'NEW',
#  'AFVD': 'BILLED',
#  'AFWD': 'BILLED',
#  'AFXD': 'BILLED',
#  'AFYD': 'BILLED',
#  'AFZD': 'FIN',
#  'AGAE': 'BILLED',
#  'AGBE': 'BILLED',
#  'AGCE': 'DELETE',
#  'AGDE': 'DELETE',
#  'AGEE': 'BILLED',
#  'AGFE': 'FIN',
#  'AGGE': 'NEW',
#  'AGHE': 'BILLED',
#  'AGIE': 'NEW',
#  'AGJE': 'FIN',
#  'AGKE': 'BILLED',
#  'AGLE': 'BILLED',
#  'AGME': 'DELETE',
#  'AGNE': 'BILLED',
#  'AGOD': 'NEW',
#  'AGOE': 'NEW',
#  'AGPD': 'FIN',
#  'AGPE': 'FIN',
#  'AGQD': 'BILLED',
#  'AGQE': 'NEW',
#  'AGRD': 'BILLED',
#  'AGSD': 'BILLED',
#  'AGTD': 'NEW',
#  'AGUD': 'DELETE',
#  'AGVD': 'BILLED',
#  'AGWD': 'BILLED',
#  'AGXD': 'DELETE',
#  'AGYD': 'BILLED',
#  'AGZD': 'FIN',
#  'AHAE': 'NEW',
#  'AHBE': 'EMPTY',
#  'AHCE': 'NEW',
#  'AHDE': 'BILLED',
#  'AHEE': 'EMPTY',
#  'AHFE': 'BILLED',
#  'AHGE': 'BILLED',
#  'AHHE': 'NEW',
#  'AHIE': 'NEW',
#  'AHJE': 'EMPTY',
#  'AHKE': 'EMPTY',
#  'AHLE': 'DELETE',
#  'AHME': 'BILLED',
#  'AHNE': 'NEW',
#  'AHOD': 'NEW',
#  'AHOE': 'BILLED',
#  'AHPD': 'BILLED',
#  'AHPE': 'NEW',
#  'AHQD': 'BILLED',
#  'AHQE': 'NEW',
#  'AHRD': 'DELETE',
#  'AHSD': 'BILLED',
#  'AHTD': 'EMPTY',
#  'AHUD': 'BILLED',
#  'AHVD': 'NEW',
#  'AHWD': 'BILLED',
#  'AHXD': 'FIN',
#  'AHYD': 'BILLED',
#  'AHZD': 'FIN',
#  'AIAE': 'NEW',
#  'AIBE': 'BILLED',
#  'AICE': 'NEW',
#  'AIDE': 'BILLED',
#  'AIEE': 'BILLED',
#  'AIFE': 'BILLED',
#  'AIGE': 'NEW',
#  'AIHE': 'NEW',
#  'AIIE': 'NEW',
#  'AIJE': 'DELETE',
#  'AIKE': 'DELETE',
#  'AILE': 'NEW',
#  'AIME': 'BILLED',
#  'AIND': 'DELETE',
#  'AINE': 'NEW',
#  'AIOD': 'NEW',
#  'AIOE': 'NEW',
#  'AIPD': 'BILLED',
#  'AIPE': 'NEW',
#  'AIQD': 'FIN',
#  'AIQE': 'NEW',
#  'AIRD': 'NEW',
#  'AISD': 'BILLED',
#  'AITD': 'BILLED',
#  'AIUD': 'BILLED',
#  'AIVD': 'BILLED',
#  'AIWD': 'BILLED',
#  'AIXD': 'NEW',
#  'AIYD': 'DELETE',
#  'AIZD': 'BILLED',
#  'AJAE': 'DELETE',
#  'AJBE': 'BILLED',
#  'AJCE': 'DELETE',
#  'AJDE': 'BILLED',
#  'AJEE': 'BILLED',
#  'AJFE': 'BILLED',
#  'AJGE': 'BILLED',
#  'AJHE': 'BILLED',
#  'AJIE': 'BILLED',
#  'AJJE': 'FIN',
#  'AJKE': 'BILLED',
#  'AJLE': 'BILLED',
#  'AJME': 'NEW',
#  'AJND': 'NEW',
#  'AJNE': 'FIN',
#  'AJOD': 'BILLED',
#  'AJOE': 'DELETE',
#  'AJPD': 'DELETE',
#  'AJPE': 'BILLED',
#  'AJQD': 'NEW',
#  'AJQE': 'NEW',
#  'AJRD': 'BILLED',
#  'AJSD': 'BILLED',
#  'AJTD': 'FIN',
#  'AJUD': 'NEW',
#  'AJVD': 'DELETE',
#  'AJWD': 'FIN',
#  'AJXD': 'BILLED',
#  'AJYD': 'BILLED',
#  'AJZD': 'NEW',
#  'AKAE': 'BILLED',
#  'AKBE': 'NEW',
#  'AKCE': 'FIN',
#  'AKDE': 'MANUAL',
#  'AKEE': 'BILLED',
#  'AKFE': 'FIN',
#  'AKGE': 'BILLED',
#  'AKHE': 'BILLED',
#  'AKIE': 'NEW',
#  'AKJE': 'BILLED',
#  'AKKE': 'NEW',
#  'AKLE': 'RELEASE',
#  'AKME': 'DELETE',
#  'AKND': 'NEW',
#  'AKNE': 'NEW',
#  'AKOD': 'BILLED',
#  'AKOE': 'FIN',
#  'AKPD': 'BILLED',
#  'AKPE': 'NEW',
#  'AKQD': 'BILLED',
#  'AKQE': 'NEW',
#  'AKRD': 'BILLED',
#  'AKSD': 'BILLED',
#  'AKTD': 'BILLED',
#  'AKUD': 'NEW',
#  'AKVD': 'BILLED',
#  'AKWD': 'BILLED',
#  'AKXD': 'BILLED',
#  'AKYD': 'BILLED',
#  'AKZD': 'BILLED',
#  'ALAE': 'BILLED',
#  'ALBE': 'NEW',
#  'ALCE': 'BILLED',
#  'ALDE': 'BILLED',
#  'ALEE': 'BILLED',
#  'ALFE': 'DELETE',
#  'ALGE': 'BILLED',
#  'ALHE': 'BILLED',
#  'ALIE': 'BILLED',
#  'ALJE': 'BILLED',
#  'ALKE': 'FIN',
#  'ALLE': 'BILLED',
#  'ALME': 'NEW',
#  'ALND': 'BILLED',
#  'ALNE': 'NEW',
#  'ALOD': 'BILLED',
#  'ALOE': 'FIN',
#  'ALPD': 'BILLED',
#  'ALPE': 'NEW',
#  'ALQD': 'BILLED',
#  'ALQE': 'NEW',
#  'ALRD': 'BILLED',
#  'ALSD': 'DELETE',
#  'ALTD': 'FIN',
#  'ALUD': 'NEW',
#  'ALVD': 'BILLED',
#  'ALWD': 'NEW',
#  'ALXD': 'BILLED',
#  'ALYD': 'BILLED',
#  'ALZD': 'FIN',
#  'AMAE': 'BILLED',
#  'AMBE': 'BILLED',
#  'AMCE': 'BILLED',
#  'AMDE': 'BILLED',
#  'AMEE': 'BILLED',
#  'AMFE': 'FIN',
#  'AMGE': 'NEW',
#  'AMHE': 'BILLED',
#  'AMIE': 'NEW',
#  'AMJE': 'BILLED',
#  'AMKE': 'NEW',
#  'AMLE': 'NEW',
#  'AMME': 'NEW',
#  'AMND': 'BILLED',
#  'AMNE': 'NEW',
#  'AMOD': 'FIN',
#  'AMOE': 'FIN',
#  'AMPD': 'BILLED',
#  'AMPE': 'NEW',
#  'AMQD': 'BILLED',
#  'AMQE': 'NEW',
#  'AMRD': 'BILLED',
#  'AMSD': 'BILLED',
#  'AMTD': 'NEW',
#  'AMUD': 'NEW',
#  'AMVD': 'BILLED',
#  'AMWD': 'FIN',
#  'AMXD': 'BILLED',
#  'AMYD': 'BILLED',
#  'AMZD': 'BILLED',
#  'ANAE': 'BILLED',
#  'ANBE': 'BILLED',
#  'ANCE': 'BILLED',
#  'ANDE': 'BILLED',
#  'ANEE': 'BILLED',
#  'ANFE': 'NEW',
#  'ANGE': 'NEW',
#  'ANHE': 'BILLED',
#  'ANIE': 'DELETE',
#  'ANJE': 'NEW',
#  'ANKE': 'NEW',
#  'ANLE': 'NEW',
#  'ANME': 'NEW',
#  'ANND': 'BILLED',
#  'ANNE': 'BILLED',
#  'ANOD': 'BILLED',
#  'ANOE': 'NEW',
#  'ANPD': 'BILLED',
#  'ANPE': 'NEW',
#  'ANQD': 'CHANGE DIAGN',
#  'ANQE': 'NEW',
#  'ANRD': 'BILLED',
#  'ANSD': 'DELETE',
#  'ANTD': 'NEW',
#  'ANUD': 'BILLED',
#  'ANVD': 'NEW',
#  'ANWD': 'BILLED',
#  'ANXD': 'NEW',
#  'ANYD': 'BILLED',
#  'ANZD': 'BILLED',
#  'AOAE': 'DELETE',
#  'AOBE': 'BILLED',
#  'AOCE': 'BILLED',
#  'AODE': 'FIN',
#  'AOEE': 'FIN',
#  'AOFE': 'BILLED',
#  'AOGE': 'NEW',
#  'AOHE': 'DELETE',
#  'AOIE': 'NEW',
#  'AOJE': 'NEW',
#  'AOKE': 'NEW',
#  'AOLE': 'NEW',
#  'AOME': 'FIN',
#  'AOND': 'BILLED',
#  'AONE': 'DELETE',
#  'AOOD': 'BILLED',
#  'AOOE': 'NEW',
#  'AOPD': 'FIN',
#  'AOPE': 'NEW',
#  'AOQD': 'NEW',
#  'AOQE': 'DELETE',
#  'AORD': 'BILLED',
#  'AOSD': 'BILLED',
#  'AOTD': 'BILLED',
#  'AOUD': 'BILLED',
#  'AOVD': 'NEW',
#  'AOWD': 'DELETE',
#  'AOXD': 'NEW',
#  'AOYD': 'BILLED',
#  'AOZD': 'BILLED',
#  'APAE': 'NEW',
#  'APBE': 'BILLED',
#  'APCE': 'BILLED',
#  'APDE': 'NEW',
#  'APEE': 'NEW',
#  'APFE': 'BILLED',
#  'APGE': 'BILLED',
#  'APHE': 'BILLED',
#  'APIE': 'NEW',
#  'APJE': 'NEW',
#  'APKE': 'BILLED',
#  'APLE': 'BILLED',
#  'APME': 'NEW',
#  'APND': 'BILLED',
#  'APNE': 'BILLED',
#  'APOD': 'DELETE',
#  'APOE': 'NEW',
#  'APPD': 'FIN',
#  'APPE': 'DELETE',
#  'APQD': 'DELETE',
#  'APQE': 'NEW',
#  'APRD': 'BILLED',
#  'APSD': 'FIN',
#  'APTD': 'BILLED',
#  'APUD': 'BILLED',
#  'APVD': 'NEW',
#  'APWD': 'BILLED',
#  'APXD': 'NEW',
#  'APYD': 'BILLED',
#  'APZD': 'NEW',
#  'AQAE': 'BILLED',
#  'AQBE': 'BILLED',
#  'AQCE': 'BILLED',
#  'AQDE': 'FIN',
#  'AQEE': 'BILLED',
#  'AQFE': 'BILLED',
#  'AQGE': 'BILLED',
#  'AQHE': 'BILLED',
#  'AQIE': 'NEW',
#  'AQJE': 'BILLED',
#  'AQKE': 'FIN',
#  'AQLE': 'BILLED',
#  'AQME': 'NEW',
#  'AQND': 'BILLED',
#  'AQNE': 'BILLED',
#  'AQOD': 'BILLED',
#  'AQOE': 'NEW',
#  'AQPD': 'EMPTY',
#  'AQPE': 'NEW',
#  'AQQD': 'BILLED',
#  'AQQE': 'NEW',
#  'AQRD': 'NEW',
#  'AQSD': 'BILLED',
#  'AQTD': 'BILLED',
#  'AQUD': 'NEW',
#  'AQVD': 'RELEASE',
#  'AQWD': 'BILLED',
#  'AQXD': 'NEW',
#  'AQYD': 'DELETE',
#  'AQZD': 'DELETE',
#  'ARAE': 'NEW',
#  'ARBE': 'BILLED',
#  'ARCE': 'BILLED',
#  'ARDE': 'NEW',
#  'AREE': 'DELETE',
#  'ARFE': 'BILLED',
#  'ARGE': 'BILLED',
#  'ARHE': 'BILLED',
#  'ARIE': 'NEW',
#  'ARJE': 'NEW',
#  'ARKE': 'BILLED',
#  'ARLE': 'BILLED',
#  'ARME': 'DELETE',
#  'ARND': 'BILLED',
#  'ARNE': 'FIN',
#  'AROD': 'DELETE',
#  'AROE': 'NEW',
#  'ARPD': 'BILLED',
#  'ARPE': 'NEW',
#  'ARQD': 'BILLED',
#  'ARQE': 'NEW',
#  'ARRD': 'BILLED',
#  'ARSD': 'BILLED',
#  'ARTD': 'FIN',
#  'ARUD': 'BILLED',
#  'ARVD': 'DELETE',
#  'ARWD': 'BILLED',
#  'ARXD': 'NEW',
#  'ARYD': 'BILLED',
#  'ARZD': 'BILLED',
#  'ASAE': 'FIN',
#  'ASBE': 'BILLED',
#  'ASCE': 'BILLED',
#  'ASDE': 'FIN',
#  'ASEE': 'BILLED',
#  'ASFE': 'NEW',
#  'ASGE': 'BILLED',
#  'ASHE': 'BILLED',
#  'ASIE': 'NEW',
#  'ASJE': 'NEW',
#  'ASKE': 'DELETE',
#  'ASLE': 'DELETE',
#  'ASME': 'NEW',
#  'ASND': 'BILLED',
#  'ASNE': 'NEW',
#  'ASOD': 'DELETE',
#  'ASOE': 'BILLED',
#  'ASPD': 'BILLED',
#  'ASPE': 'NEW',
#  'ASQD': 'EMPTY',
#  'ASQE': 'NEW',
#  'ASRD': 'BILLED',
#  'ASSD': 'BILLED',
#  'ASTD': 'BILLED',
#  'ASUD': 'BILLED',
#  'ASVD': 'BILLED',
#  'ASWD': 'BILLED',
#  'ASXD': 'NEW',
#  'ASYD': 'BILLED',
#  'ASZD': 'BILLED',
#  'ATAE': 'BILLED',
#  'ATBE': 'BILLED',
#  'ATCE': 'BILLED',
#  'ATDE': 'BILLED',
#  'ATEE': 'EMPTY',
#  'ATFE': 'NEW',
#  'ATGE': 'BILLED',
#  'ATHE': 'BILLED',
#  'ATIE': 'NEW',
#  'ATJE': 'DELETE',
#  'ATKE': 'BILLED',
#  'ATLE': 'BILLED',
#  'ATME': 'NEW',
#  'ATND': 'BILLED',
#  'ATNE': 'NEW',
#  'ATOD': 'BILLED',
#  'ATOE': 'NEW',
#  'ATPD': 'DELETE',
#  'ATPE': 'NEW',
#  'ATQD': 'BILLED',
#  'ATQE': 'NEW',
#  'ATRD': 'BILLED',
#  'ATSD': 'BILLED',
#  'ATTD': 'BILLED',
#  'ATUD': 'CODE OK',
#  'ATVD': 'DELETE',
#  'ATWD': 'NEW',
#  'ATXD': 'BILLED',
#  'ATYD': 'BILLED',
#  'ATZD': 'DELETE',
#  'AUAE': 'BILLED',
#  'AUBE': 'BILLED',
#  'AUCE': 'DELETE',
#  'AUDE': 'BILLED',
#  'AUEE': 'BILLED',
#  'AUFE': 'DELETE',
#  'AUGE': 'FIN',
#  'AUHE': 'BILLED',
#  'AUIE': 'NEW',
#  'AUJE': 'NEW',
#  'AUKE': 'NEW',
#  'AULE': 'FIN',
#  'AUME': 'NEW',
#  'AUND': 'BILLED',
#  'AUNE': 'NEW',
#  'AUOD': 'BILLED',
#  'AUOE': 'NEW',
#  'AUPD': 'NEW',
#  'AUPE': 'NEW',
#  'AUQD': 'BILLED',
#  'AUQE': 'FIN',
#  'AURD': 'NEW',
#  'AUSD': 'BILLED',
#  'AUTD': 'NEW',
#  'AUUD': 'EMPTY',
#  'AUVD': 'FIN',
#  'AUWD': 'BILLED',
#  'AUXD': 'BILLED',
#  'AUYD': 'BILLED',
#  'AUZD': 'DELETE',
#  'AVAE': 'BILLED',
#  'AVBE': 'NEW',
#  'AVCE': 'BILLED',
#  'AVDE': 'DELETE',
#  'AVEE': 'NEW',
#  'AVFE': 'BILLED',
#  'AVGE': 'BILLED',
#  'AVHE': 'NEW',
#  'AVIE': 'NEW',
#  'AVJE': 'BILLED',
#  'AVKE': 'DELETE',
#  'AVLE': 'NEW',
#  'AVME': 'NEW',
#  'AVND': 'BILLED',
#  'AVNE': 'NEW',
#  'AVOD': 'BILLED',
#  'AVOE': 'NEW',
#  'AVPD': 'NEW',
#  'AVPE': 'NEW',
#  'AVQD': 'FIN',
#  'AVQE': 'NEW',
#  'AVRD': 'BILLED',
#  'AVSD': 'BILLED',
#  'AVTD': 'BILLED',
#  'AVUD': 'DELETE',
#  'AVVD': 'BILLED',
#  'AVWD': 'BILLED',
#  'AVXD': 'BILLED',
#  'AVYD': 'BILLED',
#  'AVZD': 'BILLED',
#  'AWAE': 'BILLED',
#  'AWBE': 'BILLED',
#  'AWCE': 'NEW',
#  'AWDE': 'NEW',
#  'AWEE': 'NEW',
#  'AWFE': 'BILLED',
#  'AWGE': 'BILLED',
#  'AWHE': 'NEW',
#  'AWIE': 'NEW',
#  'AWJE': 'BILLED',
#  'AWKE': 'NEW',
#  'AWLE': 'NEW',
#  'AWME': 'NEW',
#  'AWND': 'BILLED',
#  'AWNE': 'NEW',
#  'AWOD': 'NEW',
#  'AWOE': 'NEW',
#  'AWPD': 'BILLED',
#  'AWPE': 'NEW',
#  'AWQD': 'FIN',
#  'AWQE': 'NEW',
#  'AWRD': 'BILLED',
#  'AWSD': 'NEW',
#  'AWTD': 'BILLED',
#  'AWUD': 'BILLED',
#  'AWVD': 'DELETE',
#  'AWWD': 'BILLED',
#  'AWXD': 'BILLED',
#  'AWYD': 'DELETE',
#  'AWZD': 'BILLED',
#  'AXAE': 'BILLED',
#  'AXBE': 'EMPTY',
#  'AXCE': 'BILLED',
#  'AXDE': 'BILLED',
#  'AXEE': 'BILLED',
#  'AXFE': 'BILLED',
#  'AXGE': 'BILLED',
#  'AXHE': 'NEW',
#  'AXIE': 'NEW',
#  'AXJE': 'NEW',
#  'AXKE': 'NEW',
#  'AXLE': 'BILLED',
#  'AXME': 'BILLED',
#  'AXND': 'BILLED',
#  'AXNE': 'NEW',
#  'AXOD': 'BILLED',
#  'AXOE': 'NEW',
#  'AXPD': 'NEW',
#  'AXPE': 'NEW',
#  'AXQD': 'FIN',
#  'AXQE': 'NEW',
#  'AXRD': 'BILLED',
#  'AXSD': 'BILLED',
#  'AXTD': 'DELETE',
#  'AXUD': 'FIN',
#  'AXVD': 'BILLED',
#  'AXWD': 'BILLED',
#  'AXXD': 'FIN',
#  'AXYD': 'NEW',
#  'AXZD': 'NEW',
#  'AYAE': 'BILLED',
#  'AYBE': 'NEW',
#  'AYCE': 'BILLED',
#  'AYDE': 'BILLED',
#  'AYEE': 'DELETE',
#  'AYFE': 'BILLED',
#  'AYGE': 'BILLED',
#  'AYHE': 'NEW',
#  'AYIE': 'FIN',
#  'AYJE': 'NEW',
#  'AYKE': 'BILLED',
#  'AYLE': 'NEW',
#  'AYME': 'EMPTY',
#  'AYND': 'BILLED',
#  'AYNE': 'FIN',
#  'AYOD': 'BILLED',
#  'AYOE': 'NEW',
#  'AYPD': 'BILLED',
#  'AYPE': 'FIN',
#  'AYQD': 'DELETE',
#  'AYRD': 'NEW',
#  'AYSD': 'NEW',
#  'AYTD': 'BILLED',
#  'AYUD': 'BILLED',
#  'AYVD': 'BILLED',
#  'AYWD': 'BILLED',
#  'AYXD': 'BILLED',
#  'AYYD': 'DELETE',
#  'AYZD': 'NEW',
#  'AZAE': 'FIN',
#  'AZBE': 'NEW',
#  'AZCE': 'NEW',
#  'AZDE': 'BILLED',
#  'AZEE': 'BILLED',
#  'AZFE': 'BILLED',
#  'AZGE': 'BILLED',
#  'AZHE': 'NEW',
#  'AZIE': 'BILLED',
#  'AZJE': 'NEW',
#  'AZKE': 'NEW',
#  'AZLE': 'DELETE',
#  'AZME': 'NEW',
#  'AZND': 'BILLED',
#  'AZNE': 'NEW',
#  'AZOD': 'BILLED',
#  'AZOE': 'BILLED',
#  'AZPD': 'BILLED',
#  'AZPE': 'FIN',
#  'AZQD': 'DELETE',
#  'AZRD': 'NEW',
#  'AZSD': 'NEW',
#  'AZTD': 'FIN',
#  'AZUD': 'BILLED',
#  'AZVD': 'NEW',
#  'AZWD': 'BILLED',
#  'AZXD': 'BILLED',
#  'AZYD': 'BILLED',
#  'AZZD': 'NEW',
#  'BAAE': 'BILLED',
#  'BABE': 'BILLED',
#  'BACE': 'NEW',
#  'BADE': 'NEW',
#  'BAEE': 'BILLED',
#  'BAFE': 'BILLED',
#  'BAGE': 'NEW',
#  'BAHE': 'NEW',
#  'BAIE': 'NEW',
#  'BAJE': 'DELETE',
#  'BAKE': 'BILLED',
#  'BALE': 'NEW',
#  'BAME': 'DELETE',
#  'BANE': 'NEW',
#  'BAOD': 'BILLED',
#  'BAOE': 'NEW',
#  'BAPD': 'NEW',
#  'BAPE': 'NEW',
#  'BAQD': 'BILLED',
#  'BAQE': 'NEW',
#  'BARD': 'BILLED',
#  'BASD': 'NEW',
#  'BATD': 'NEW',
#  'BAUD': 'BILLED',
#  'BAVD': 'FIN',
#  'BAWD': 'BILLED',
#  'BAXD': 'NEW',
#  'BAYD': 'BILLED',
#  'BAZD': 'BILLED',
#  'BBAE': 'BILLED',
#  'BBBE': 'DELETE',
#  'BBCE': 'BILLED',
#  'BBDE': 'BILLED',
#  'BBEE': 'EMPTY',
#  'BBFE': 'FIN',
#  'BBGE': 'BILLED',
#  'BBHE': 'NEW',
#  'BBIE': 'NEW',
#  'BBJE': 'FIN',
#  'BBKE': 'NEW',
#  'BBLE': 'NEW',
#  'BBME': 'FIN',
#  'BBNE': 'NEW',
#  'BBOD': 'BILLED',
#  'BBOE': 'NEW',
#  'BBPD': 'NEW',
#  'BBPE': 'DELETE',
#  'BBQD': 'FIN',
#  'BBQE': 'DELETE',
#  'BBRD': 'FIN',
#  'BBSD': 'NEW',
#  'BBTD': 'NEW',
#  'BBUD': 'DELETE',
#  'BBVD': 'NEW',
#  'BBWD': 'BILLED',
#  'BBXD': 'BILLED',
#  'BBYD': 'BILLED',
#  'BBZD': 'BILLED',
#  'BCAE': 'BILLED',
#  'BCBE': 'BILLED',
#  'BCCE': 'FIN',
#  'BCDE': 'BILLED',
#  'BCEE': 'BILLED',
#  'BCFE': 'BILLED',
#  'BCGE': 'BILLED',
#  'BCHE': 'BILLED',
#  'BCIE': 'NEW',
#  'BCJE': 'BILLED',
#  'BCKE': 'BILLED',
#  'BCLE': 'DELETE',
#  'BCME': 'NEW',
#  'BCNE': 'BILLED',
#  'BCOD': 'NEW',
#  'BCOE': 'NEW',
#  'BCPD': 'NEW',
#  'BCPE': 'NEW',
#  'BCQD': 'BILLED',
#  'BCQE': 'NEW',
#  'BCRD': 'BILLED',
#  'BCSD': 'NEW',
#  'BCTD': 'NEW',
#  'BCUD': 'NEW',
#  'BCVD': 'NEW',
#  'BCWD': 'FIN',
#  'BCXD': 'DELETE',
#  'BCYD': 'BILLED',
#  'BCZD': 'NEW',
#  'BDAE': 'DELETE',
#  'BDBE': 'DELETE',
#  'BDCE': 'NEW',
#  'BDDE': 'NEW',
#  'BDEE': 'BILLED',
#  'BDFE': 'FIN',
#  'BDGE': 'FIN',
#  'BDHE': 'NEW',
#  'BDIE': 'BILLED',
#  'BDJE': 'NEW',
#  'BDKE': 'FIN',
#  'BDLE': 'BILLED',
#  'BDME': 'BILLED',
#  'BDNE': 'CHANGE DIAGN',
#  'BDOD': 'BILLED',
#  'BDOE': 'NEW',
#  'BDPD': 'BILLED',
#  'BDPE': 'NEW',
#  'BDQD': 'BILLED',
#  'BDQE': 'NEW',
#  'BDRD': 'BILLED',
#  'BDSD': 'BILLED',
#  'BDTD': 'NEW',
#  'BDUD': 'BILLED',
#  'BDVD': 'NEW',
#  'BDWD': 'DELETE',
#  'BDXD': 'BILLED',
#  'BDYD': 'BILLED',
#  'BDZD': 'NEW',
#  'BEAE': 'BILLED',
#  'BEBE': 'NEW',
#  'BECE': 'BILLED',
#  'BEDE': 'BILLED',
#  'BEEE': 'DELETE',
#  'BEFE': 'FIN',
#  'BEGE': 'BILLED',
#  'BEHE': 'BILLED',
#  'BEIE': 'BILLED',
#  'BEJE': 'NEW',
#  'BEKE': 'BILLED',
#  'BELE': 'NEW',
#  'BEME': 'NEW',
#  'BENE': 'BILLED',
#  'BEOD': 'BILLED',
#  'BEOE': 'NEW',
#  'BEPD': 'BILLED',
#  'BEPE': 'NEW',
#  'BEQD': 'BILLED',
#  'BEQE': 'NEW',
#  'BERD': 'BILLED',
#  'BESD': 'BILLED',
#  'BETD': 'NEW',
#  'BEUD': 'BILLED',
#  'BEVD': 'NEW',
#  'BEWD': 'BILLED',
#  'BEXD': 'NEW',
#  'BEYD': 'NEW',
#  'BEZD': 'DELETE',
#  'BFAE': 'BILLED',
#  'BFBE': 'BILLED',
#  'BFCE': 'FIN',
#  'BFDE': 'DELETE',
#  'BFEE': 'BILLED',
#  'BFFE': 'BILLED',
#  'BFGE': 'NEW',
#  'BFHE': 'BILLED',
#  'BFIE': 'DELETE',
#  'BFJE': 'NEW',
#  'BFKE': 'DELETE',
#  'BFLE': 'NEW',
#  'BFME': 'FIN',
#  'BFNE': 'DELETE',
#  'BFOD': 'BILLED',
#  'BFOE': 'NEW',
#  'BFPD': 'FIN',
#  'BFPE': 'NEW',
#  'BFQD': 'BILLED',
#  'BFQE': 'NEW',
#  'BFRD': 'BILLED',
#  'BFSD': 'BILLED',
#  'BFTD': 'DELETE',
#  'BFUD': 'NEW',
#  'BFVD': 'BILLED',
#  'BFWD': 'BILLED',
#  'BFXD': 'BILLED',
#  'BFYD': 'BILLED',
#  'BFZD': 'BILLED',
#  'BGAE': 'BILLED',
#  'BGBE': 'BILLED',
#  'BGCE': 'BILLED',
#  'BGDE': 'FIN',
#  'BGEE': 'BILLED',
#  'BGFE': 'DELETE',
#  'BGGE': 'NEW',
#  'BGHE': 'BILLED',
#  'BGIE': 'NEW',
#  'BGJE': 'BILLED',
#  'BGKE': 'CODE OK',
#  'BGLE': 'FIN',
#  'BGME': 'BILLED',
#  'BGNE': 'BILLED',
#  'BGOD': 'NEW',
#  'BGOE': 'NEW',
#  'BGPD': 'BILLED',
#  'BGPE': 'FIN',
#  'BGQD': 'EMPTY',
#  'BGQE': 'NEW',
#  'BGRD': 'BILLED',
#  'BGSD': 'BILLED',
#  'BGTD': 'EMPTY',
#  'BGUD': 'BILLED',
#  'BGVD': 'BILLED',
#  'BGWD': 'BILLED',
#  'BGXD': 'DELETE',
#  'BGYD': 'BILLED',
#  'BGZD': 'BILLED',
#  'BHAE': 'NEW',
#  'BHBE': 'NEW',
#  'BHCE': 'NEW',
#  'BHDE': 'BILLED',
#  'BHEE': 'BILLED',
#  'BHFE': 'BILLED',
#  'BHGE': 'BILLED',
#  'BHHE': 'NEW',
#  'BHIE': 'NEW',
#  'BHJE': 'BILLED',
#  'BHKE': 'FIN',
#  'BHLE': 'FIN',
#  'BHME': 'BILLED',
#  'BHNE': 'NEW',
#  'BHOD': 'NEW',
#  'BHOE': 'DELETE',
#  'BHPD': 'BILLED',
#  'BHPE': 'FIN',
#  'BHQD': 'BILLED',
#  'BHQE': 'NEW',
#  'BHRD': 'EMPTY',
#  'BHSD': 'BILLED',
#  'BHTD': 'FIN',
#  'BHUD': 'BILLED',
#  'BHVD': 'NEW',
#  'BHWD': 'BILLED',
#  'BHXD': 'BILLED',
#  ...}

# %%
import yaml
with open('ppm_benchmark/benchmark_configs/test_config.yaml', 'r') as file:
        config = yaml.safe_load(file)
        
config.get('datasets')
# Out:
# [{'name': 'Hospital Billing',
#   'dataset_normalizer': 'StandardXes',
#   'dataset_loader': 'RemoteZippedXesGz',
#   'data_path': 'https://data.4tu.nl/ndownloader/items/6af6d5f0-f44c-49be-aac8-8eaa5fe4f6fd/versions/1',
#   'is_remote': True,
#   'data_owner': 'Felix Mannhardt',
#   'tasks': [{'name': 'test_task'}]}]

# %%
from ppm_benchmark.core.benchmark_loader import BenchmarkLoader


loader = BenchmarkLoader()

benchmark = loader.load_from_config('ppm_benchmark/benchmark_configs/test_config.yaml')
# Out:
# Downloading Hospital Billing dataset by Felix Mannhardt from https://data.4tu.nl/ndownloader/items/6af6d5f0-f44c-49be-aac8-8eaa5fe4f6fd/versions/1
# C:\Users\Dell\OneDrive - Universiteit Leiden\Thesis\ppm_benchmark\env\lib\site-packages\pm4py\util\dt_parsing\parser.py:77: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
import random
from ppm_benchmark.core.benchmark_loader import BenchmarkLoader


loader = BenchmarkLoader()
benchmark = loader.load_from_folder('test_benchmark')

tasks = benchmark.get_tasks()
tasks
# Out:
# ['test_task']

# %%
task = benchmark.load_task('test_task')

preds = dict()
train_df = task.get_train_data()
test_df = task.get_test_data()
targets = train_df['concept:name'].unique().tolist()

for index, row in test_df.iterrows():
        pred = random.choice(targets)
        case_id = row['case:concept:name']
        preds[case_id] = pred
benchmark.evaluate(task, preds)
# Out:
# Evaluation metrics for task test_task:
# 	 accuracy: 0.05305

# %%
from ppm_benchmark.core.experiment import Experiment


experiment = Experiment()
experiment.new_experiment('test_experiment')

task = benchmark.load_task('test_task')
run_tracker, run = experiment.init_run(task, 'test_run')

for i in range(0, 10):
        run_tracker.epoch_end({'loss': 0})

run_tracker.train_end()
run_tracker.evaluate(preds)
# Out:
# Run test_run for task test_task finished.
# Completed in 9 epochs
# Training time: 0.0 minutes
# Test set metrics: {'accuracy': 0.05305}

# %%
run.to_dict()
# Out:
# {'task': 'test_task',
#  'run_id': 'test_run',
#  'start_time': datetime.datetime(2024, 6, 6, 15, 35, 37, 23857),
#  'end_time': datetime.datetime(2024, 6, 6, 15, 35, 37, 23857),
#  'training_time': 0.0,
#  'test_metrics': {'accuracy': 0.05305},
#  'epochs': {1: {'loss': 0},
#   2: {'loss': 0},
#   3: {'loss': 0},
#   4: {'loss': 0},
#   5: {'loss': 0},
#   6: {'loss': 0},
#   7: {'loss': 0},
#   8: {'loss': 0},
#   9: {'loss': 0}},
#  'hyper_params': {}}

# %%
from py2puml.py2puml import py2puml

print(''.join(py2puml('ppm_benchmark', 'ppm_benchmark')))
# Out:
# @startuml ppm_benchmark
# !pragma useIntermediatePackages false
#
# abstract class ppm_benchmark.Models.BaseDatasetLoader.BaseDatasetLoader {
# }
# class ppm_benchmark.DatasetLoaders.RemoteZippedXesGz.RemoteZippedXesGz {
# }
# abstract class ppm_benchmark.Models.BaseDatasetNormalizer.BaseDatasetNormalizer {
# }
# class ppm_benchmark.DatasetNormalizers.StandardXes.StandardXes {
# }
# class ppm_benchmark.Metrics.Accuracy.Accuracy {
# }
# abstract class ppm_benchmark.Models.BaseMetric.BaseMetric {
#   name: None
# }
# abstract class ppm_benchmark.Models.BaseTaskGenerator.BaseTaskGenerator {
#   name: None
# }
# class ppm_benchmark.Models.Benchmark.Benchmark {
#   name: None
#   tasks: None
#   evaluations_dict: None
# }
# class ppm_benchmark.Models.Benchmark.TaskNotFoundError {
# }
# class ppm_benchmark.Models.Dataset.Dataset {
#   name: None
#   dataset_normalizer: None
#   dataset_loader: None
#   data_path: None
#   is_remote: None
#   data_owner: None
# }
# class ppm_benchmark.Models.Run.Run {
#   task: None
#   run_id: None
#   start_time: None
#   end_time: None
#   training_time: None
#   test_metrics: None
#   epochs: None
#   hyper_params: None
# }
# class ppm_benchmark.Models.Task.Task {
#   name: None
#   metrics: None
#   task_generator: None
#   save_folder: None
#   category: None
# }
# class ppm_benchmark.TaskGenerators.SimpleClassificationGenerator.SimpleClassificationGenerator {
# }
# class ppm_benchmark.core.benchmark_loader.BenchmarkLoader {
# }
# class ppm_benchmark.core.experiment.Experiment {
#   name: None
#   runs: None
# }
# class ppm_benchmark.core.experiment.GenericCallback {
#   experiment: None
#   task: None
#   run_id: None
#   epochs: None
# }
# class ppm_benchmark.core.experiment.RunNotFoundError {
# }
# class ppm_benchmark.core.experiment.TFCallback {
#   experiment: None
#   task: None
#   run_id: None
#   epochs: None
# }
# ppm_benchmark.Models.BaseDatasetLoader.BaseDatasetLoader <|-- ppm_benchmark.DatasetLoaders.RemoteZippedXesGz.RemoteZippedXesGz
# ppm_benchmark.Models.BaseDatasetNormalizer.BaseDatasetNormalizer <|-- ppm_benchmark.DatasetNormalizers.StandardXes.StandardXes
# ppm_benchmark.Models.BaseMetric.BaseMetric <|-- ppm_benchmark.Metrics.Accuracy.Accuracy
# ppm_benchmark.Models.BaseTaskGenerator.BaseTaskGenerator <|-- ppm_benchmark.TaskGenerators.SimpleClassificationGenerator.SimpleClassificationGenerator
# footer Generated by //py2puml//
# @enduml
